# %%
sales = 5_300_000
expenses = 2_600_000
taxes = 875_000
year = 2025
profit = sales - expenses - taxes
print(f"In {year} Acme had ${sales:,} in widget sales, ${expenses:,} in expenses, and ${taxes:,} in taxes. Profit is ${profit:,}")
# Out:
# In 2025 Acme had $5,300,000 in widget sales, $2,600,000 in expenses, and $875,000 in taxes. Profit is $1,825,000

# %%
#return positive number
abs(-15)
# Out:
# 15

# %%
#how long is this phrase? doesn't work with numbers
len("grace")
# Out:
# 5

# %%
type(45)
# Out:
# int

# %%
#create a list with terms
animals = ["rat", "cat", "dog", "bee"]
print(type(animals))
#show that there are 4 items in the "length" of the animals list 
print(len(animals))
# Out:
# <class 'list'>
# 4

# %%
#build and call car_1 dictionary
Car_1 = {"brand": "Audi", "body":"SUV", "model":"Q4", "trim":"leather",
 "cost":60_000, "on_sale":False, "vin":2973, "type":"EV"}
Car_1
# Out:
# {'brand': 'Audi',
#  'body': 'SUV',
#  'model': 'Q4',
#  'trim': 'leather',
#  'cost': 60000,
#  'on_sale': False,
#  'vin': 2973,
#  'type': 'EV'}

# %%
#import library
import pandas as pd

# %%
#read csv file when data file is in same level
pd.read_csv("insurance.csv")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
