# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib
from openpyxl import Workbook

print(f"Python: {sys.version}")
print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"Seaborn: {sns.__version__}")
print(f"Plotly: {px.__version__}")
print("\n All packages loaded successfully!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Python: 3.11.14 | packaged by conda-forge | (main, Jan 27 2026, 00:01:01) [Clang 19.1.7 ]
# NumPy: 2.4.2
# Pandas: 3.0.0
# Matplotlib: 3.10.8
# Seaborn: 0.13.2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      13 print(f"Matplotlib: {matplotlib.__version__}")
#      14 print(f"Seaborn: {sns.__version__}")
# ---> 15 print(f"Plotly: {px.__version__}")
#      16 print("\n All packages loaded successfully!")
#
# AttributeError: module 'plotly.express' has no attribute '__version__'

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /Users/gracet/miniforge3/envs/dataj-installs/lib/python3.11/site-packages (6.5.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/gracet/miniforge3/envs/dataj-installs/lib/python3.11/site-packages (from plotly) (2.16.0)
# Requirement already satisfied: packaging in /Users/gracet/miniforge3/envs/dataj-installs/lib/python3.11/site-packages (from plotly) (26.0)
# Note: you may need to restart the kernel to use updated packages.
